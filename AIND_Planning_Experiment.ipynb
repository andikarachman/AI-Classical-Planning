# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

# %matplotlib inline

# %% [markdown]
# ## Problem 1

# %%
BFS_actions_1 = 20
BFS_expansions_1 = 43
BFS_goal_tests_1 = 56
BFS_new_nodes_1 = 178
BFS_plan_length_1 = 6
BFS_time_elapsed_1 = 0.0059977269265800714
        
DFGS_actions_1 = 20
DFGS_expansions_1 = 21
DFGS_goal_tests_1 = 22
DFGS_new_nodes_1 = 84
DFGS_plan_length_1 = 20
DFGS_time_elapsed_1 = 0.00321715185418725

UCS_actions_1 = 20
UCS_expansions_1 = 60
UCS_goal_tests_1 = 62
UCS_new_nodes_1 = 240
UCS_plan_length_1 = 6
UCS_time_elapsed_1 = 0.01278993091545999
        
GBFGS_h_unmet_actions_1 = 20
GBFGS_h_unmet_expansions_1 = 7
GBFGS_h_unmet_goal_tests_1 = 9
GBFGS_h_unmet_new_nodes_1 = 29
GBFGS_h_unmet_plan_length_1 = 6
GBFGS_h_unmet_time_elapsed_1 = 0.0018109891097992659
        
GBFGS_h_pg_levelsum_actions_1 = 20
GBFGS_h_pg_levelsum_expansions_1 = 6
GBFGS_h_pg_levelsum_goal_tests_1 = 8
GBFGS_h_pg_levelsum_new_nodes_1 = 28
GBFGS_h_pg_levelsum_plan_length_1 = 6
GBFGS_h_pg_levelsum_time_elapsed_1 = 0.2570220110937953
    
GBFGS_h_pg_maxlevel_actions_1 = 20
GBFGS_h_pg_maxlevel_expansions_1 = 6
GBFGS_h_pg_maxlevel_goal_tests_1 = 8
GBFGS_h_pg_maxlevel_new_nodes_1 = 24
GBFGS_h_pg_maxlevel_plan_length_1 = 6
GBFGS_h_pg_maxlevel_time_elapsed_1 = 0.18564468994736671 
        
GBFGS_h_pg_setlevel_actions_1 = 20
GBFGS_h_pg_setlevel_expansions_1 = 6
GBFGS_h_pg_setlevel_goal_tests_1 = 8
GBFGS_h_pg_setlevel_new_nodes_1 = 28
GBFGS_h_pg_setlevel_plan_length_1 = 6
GBFGS_h_pg_setlevel_time_elapsed_1 = 0.6430527591146529
        
Astar_search_h_unmet_actions_1 = 20
Astar_search_h_unmet_expansions_1 = 50
Astar_search_h_unmet_goal_tests_1 = 52
Astar_search_h_unmet_new_nodes_1 = 206
Astar_search_h_unmet_plan_length_1 = 6
Astar_search_h_unmet_time_elapsed_1 = 0.00953388912603259
        
Astar_search_h_pg_levelsum_actions_1 = 20
Astar_search_h_pg_levelsum_expansions_1 = 28
Astar_search_h_pg_levelsum_goal_tests_1 = 30
Astar_search_h_pg_levelsum_new_nodes_1 = 122
Astar_search_h_pg_levelsum_plan_length_1 = 6
Astar_search_h_pg_levelsum_time_elapsed_1 = 0.6331071050371975
        
Astar_search_h_pg_maxlevel_actions_1 = 20
Astar_search_h_pg_maxlevel_expansions_1 = 43
Astar_search_h_pg_maxlevel_goal_tests_1 = 45
Astar_search_h_pg_maxlevel_new_nodes_1 = 180
Astar_search_h_pg_maxlevel_plan_length_1 = 6
Astar_search_h_pg_maxlevel_time_elapsed_1 = 0.6404850448016077
        
Astar_search_h_pg_setlevel_actions_1 = 20
Astar_search_h_pg_setlevel_expansions_1 = 33
Astar_search_h_pg_setlevel_goal_tests_1 = 35
Astar_search_h_pg_setlevel_new_nodes_1 = 138
Astar_search_h_pg_setlevel_plan_length_1 = 6
Astar_search_h_pg_setlevel_time_elapsed_1 = 1.4159884459804744

# %%
columns = ['Actions','Expansions','Goal_Tests','New_Nodes','Plan_Length','Time_Elapsed']
index = ['Breadth_First_Search', 'Depth_First_Graph_Search', 'Uniform_Cost_Search', 
         'Greedy_Best_First_Graph_Search_H_Unmet_Goals', 'Greedy_Best_First_Graph_Search_H_PG_Levelsum',
         'Greedy_Best_First_Graph_Search H_PG_Maxlevel', 'Greedy_Best_First_Graph_Search_H_PG_Setlevel',
         'Astar_Search_H_Unmet_Goals', 'Astar_Search_H_PG_Levelsum', 'Astar_Search_H_PG_Maxlevel',
         'Astar_Search H_PG_Setlevel']
data_problem_1 = [[BFS_actions_1, BFS_expansions_1, BFS_goal_tests_1, BFS_new_nodes_1, BFS_plan_length_1, BFS_time_elapsed_1],
                 [DFGS_actions_1, DFGS_expansions_1, DFGS_goal_tests_1, DFGS_new_nodes_1, DFGS_plan_length_1, DFGS_time_elapsed_1],
                 [UCS_actions_1, UCS_expansions_1, UCS_goal_tests_1, UCS_new_nodes_1, UCS_plan_length_1, UCS_time_elapsed_1],
                 [GBFGS_h_unmet_actions_1, GBFGS_h_unmet_expansions_1, GBFGS_h_unmet_goal_tests_1, GBFGS_h_unmet_new_nodes_1, GBFGS_h_unmet_plan_length_1, GBFGS_h_unmet_time_elapsed_1],
                 [GBFGS_h_pg_levelsum_actions_1, GBFGS_h_pg_levelsum_expansions_1, GBFGS_h_pg_levelsum_goal_tests_1, GBFGS_h_pg_levelsum_new_nodes_1, GBFGS_h_pg_levelsum_plan_length_1, GBFGS_h_pg_levelsum_time_elapsed_1],
                 [GBFGS_h_pg_maxlevel_actions_1, GBFGS_h_pg_maxlevel_expansions_1, GBFGS_h_pg_maxlevel_goal_tests_1, GBFGS_h_pg_maxlevel_new_nodes_1, GBFGS_h_pg_maxlevel_plan_length_1, GBFGS_h_pg_maxlevel_time_elapsed_1],
                 [GBFGS_h_pg_setlevel_actions_1, GBFGS_h_pg_setlevel_expansions_1, GBFGS_h_pg_setlevel_goal_tests_1, GBFGS_h_pg_setlevel_new_nodes_1, GBFGS_h_pg_setlevel_plan_length_1, GBFGS_h_pg_setlevel_time_elapsed_1],
                 [Astar_search_h_unmet_actions_1, Astar_search_h_unmet_expansions_1, Astar_search_h_unmet_goal_tests_1, Astar_search_h_unmet_new_nodes_1, Astar_search_h_unmet_plan_length_1, Astar_search_h_unmet_time_elapsed_1],
                 [Astar_search_h_pg_levelsum_actions_1, Astar_search_h_pg_levelsum_expansions_1, Astar_search_h_pg_levelsum_goal_tests_1, Astar_search_h_pg_levelsum_new_nodes_1, Astar_search_h_pg_levelsum_plan_length_1, Astar_search_h_pg_levelsum_time_elapsed_1],
                 [Astar_search_h_pg_maxlevel_actions_1, Astar_search_h_pg_maxlevel_expansions_1, Astar_search_h_pg_maxlevel_goal_tests_1, Astar_search_h_pg_maxlevel_new_nodes_1, Astar_search_h_pg_maxlevel_plan_length_1, Astar_search_h_pg_maxlevel_time_elapsed_1],
                 [Astar_search_h_pg_setlevel_actions_1, Astar_search_h_pg_setlevel_expansions_1, Astar_search_h_pg_setlevel_goal_tests_1, Astar_search_h_pg_setlevel_new_nodes_1, Astar_search_h_pg_setlevel_plan_length_1, Astar_search_h_pg_setlevel_time_elapsed_1]]

problem1_df = pd.DataFrame(data=data_problem_1, columns = columns, index = index)
problem1_df
# Out:
#                                               Actions  Expansions  Goal_Tests  \
# Breadth_First_Search                               20          43          56
# Depth_First_Graph_Search                           20          21          22
# Uniform_Cost_Search                                20          60          62
# Greedy_Best_First_Graph_Search_H_Unmet_Goals       20           7           9
# Greedy_Best_First_Graph_Search_H_PG_Levelsum       20           6           8
# Greedy_Best_First_Graph_Search H_PG_Maxlevel       20           6           8
# Greedy_Best_First_Graph_Search_H_PG_Setlevel       20           6           8
# Astar_Search_H_Unmet_Goals                         20          50          52
# Astar_Search_H_PG_Levelsum                         20          28          30
# Astar_Search_H_PG_Maxlevel                         20          43          45
# Astar_Search H_PG_Setlevel                         20          33          35
#
# ...

# %% [markdown]
# ## Problem 2

# %%
BFS_actions_2 = 72
BFS_expansions_2 = 3343
BFS_goal_tests_2 = 4609
BFS_new_nodes_2 = 30503
BFS_plan_length_2 = 9
BFS_time_elapsed_2 = 2.0109402269590646
              
DFGS_actions_2 = 72
DFGS_expansions_2 = 624
DFGS_goal_tests_2 = 625
DFGS_new_nodes_2 = 5602
DFGS_plan_length_2 = 619
DFGS_time_elapsed_2 = 2.6814636269118637
            
UCS_actions_2 = 72
UCS_expansions_2 = 5154
UCS_goal_tests_2 = 5156
UCS_new_nodes_2 = 46618
UCS_plan_length_2 = 9
UCS_time_elapsed_2 = 3.2812032541260123
        
GBFGS_h_unmet_actions_2 = 72
GBFGS_h_unmet_expansions_2 = 17
GBFGS_h_unmet_goal_tests_2 = 19
GBFGS_h_unmet_new_nodes_2 = 170
GBFGS_h_unmet_plan_length_2 = 9
GBFGS_h_unmet_time_elapsed_2 = 0.017724145902320743
        
GBFGS_h_pg_levelsum_actions_2 = 72
GBFGS_h_pg_levelsum_expansions_2 = 9
GBFGS_h_pg_levelsum_goal_tests_2 = 11
GBFGS_h_pg_levelsum_new_nodes_2 = 86
GBFGS_h_pg_levelsum_plan_length_2 = 9
GBFGS_h_pg_levelsum_time_elapsed_2 = 5.927120839012787

GBFGS_h_pg_maxlevel_actions_2 = 72
GBFGS_h_pg_maxlevel_expansions_2 = 27
GBFGS_h_pg_maxlevel_goal_tests_2 = 29
GBFGS_h_pg_maxlevel_new_nodes_2 = 249
GBFGS_h_pg_maxlevel_plan_length_2 = 9
GBFGS_h_pg_maxlevel_time_elapsed_2 = 13.615322675090283 

GBFGS_h_pg_setlevel_actions_2 = 72
GBFGS_h_pg_setlevel_expansions_2 = 9
GBFGS_h_pg_setlevel_goal_tests_2 = 11
GBFGS_h_pg_setlevel_new_nodes_2 = 84
GBFGS_h_pg_setlevel_plan_length_2 = 9
GBFGS_h_pg_setlevel_time_elapsed_2 = 15.721597005147487
        
Astar_search_h_unmet_actions_2 = 72
Astar_search_h_unmet_expansions_2 = 2467
Astar_search_h_unmet_goal_tests_2 = 2469
Astar_search_h_unmet_new_nodes_2 = 22522
Astar_search_h_unmet_plan_length_2 = 9
Astar_search_h_unmet_time_elapsed_2 = 2.3889053789898753
        
Astar_search_h_pg_levelsum_actions_2 = 72
Astar_search_h_pg_levelsum_expansions_2 = 357
Astar_search_h_pg_levelsum_goal_tests_2 = 359
Astar_search_h_pg_levelsum_new_nodes_2 = 3426
Astar_search_h_pg_levelsum_plan_length_2 = 9
Astar_search_h_pg_levelsum_time_elapsed_2 = 167.09634639602154

Astar_search_h_pg_maxlevel_actions_2 = 72
Astar_search_h_pg_maxlevel_expansions_2 = 2887
Astar_search_h_pg_maxlevel_goal_tests_2 = 2889
Astar_search_h_pg_maxlevel_new_nodes_2 = 26594
Astar_search_h_pg_maxlevel_plan_length_2 = 9
Astar_search_h_pg_maxlevel_time_elapsed_2 = 981.520005205879

Astar_search_h_pg_setlevel_actions_2 = 72
Astar_search_h_pg_setlevel_expansions_2 = 1037
Astar_search_h_pg_setlevel_goal_tests_2 = 1039
Astar_search_h_pg_setlevel_new_nodes_2 = 9605
Astar_search_h_pg_setlevel_plan_length_2 = 9
Astar_search_h_pg_setlevel_time_elapsed_2 = 1343.51019709697

# %%
data_problem_2 = [[BFS_actions_2, BFS_expansions_2, BFS_goal_tests_2, BFS_new_nodes_2, BFS_plan_length_2, BFS_time_elapsed_2],
                 [DFGS_actions_2, DFGS_expansions_2, DFGS_goal_tests_2, DFGS_new_nodes_2, DFGS_plan_length_2, DFGS_time_elapsed_2],
                 [UCS_actions_2, UCS_expansions_2, UCS_goal_tests_2, UCS_new_nodes_2, UCS_plan_length_2, UCS_time_elapsed_2],
                 [GBFGS_h_unmet_actions_2, GBFGS_h_unmet_expansions_2, GBFGS_h_unmet_goal_tests_2, GBFGS_h_unmet_new_nodes_2, GBFGS_h_unmet_plan_length_2, GBFGS_h_unmet_time_elapsed_2],
                 [GBFGS_h_pg_levelsum_actions_2, GBFGS_h_pg_levelsum_expansions_2, GBFGS_h_pg_levelsum_goal_tests_2, GBFGS_h_pg_levelsum_new_nodes_2, GBFGS_h_pg_levelsum_plan_length_2, GBFGS_h_pg_levelsum_time_elapsed_2],
                 [GBFGS_h_pg_maxlevel_actions_2, GBFGS_h_pg_maxlevel_expansions_2, GBFGS_h_pg_maxlevel_goal_tests_2, GBFGS_h_pg_maxlevel_new_nodes_2, GBFGS_h_pg_maxlevel_plan_length_2, GBFGS_h_pg_maxlevel_time_elapsed_2],
                 [GBFGS_h_pg_setlevel_actions_2, GBFGS_h_pg_setlevel_expansions_2, GBFGS_h_pg_setlevel_goal_tests_2, GBFGS_h_pg_setlevel_new_nodes_2, GBFGS_h_pg_setlevel_plan_length_2, GBFGS_h_pg_setlevel_time_elapsed_2],
                 [Astar_search_h_unmet_actions_2, Astar_search_h_unmet_expansions_2, Astar_search_h_unmet_goal_tests_2, Astar_search_h_unmet_new_nodes_2, Astar_search_h_unmet_plan_length_2, Astar_search_h_unmet_time_elapsed_2],
                 [Astar_search_h_pg_levelsum_actions_2, Astar_search_h_pg_levelsum_expansions_2, Astar_search_h_pg_levelsum_goal_tests_2, Astar_search_h_pg_levelsum_new_nodes_2, Astar_search_h_pg_levelsum_plan_length_2, Astar_search_h_pg_levelsum_time_elapsed_2],
                 [Astar_search_h_pg_maxlevel_actions_2, Astar_search_h_pg_maxlevel_expansions_2, Astar_search_h_pg_maxlevel_goal_tests_2, Astar_search_h_pg_maxlevel_new_nodes_2, Astar_search_h_pg_maxlevel_plan_length_2, Astar_search_h_pg_maxlevel_time_elapsed_2],
                 [Astar_search_h_pg_setlevel_actions_2, Astar_search_h_pg_setlevel_expansions_2, Astar_search_h_pg_setlevel_goal_tests_2, Astar_search_h_pg_setlevel_new_nodes_2, Astar_search_h_pg_setlevel_plan_length_2, Astar_search_h_pg_setlevel_time_elapsed_2]]

problem2_df = pd.DataFrame(data=data_problem_2, columns=columns, index=index)
problem2_df
# Out:
#                                               Actions  Expansions  Goal_Tests  \
# Breadth_First_Search                               72        3343        4609
# Depth_First_Graph_Search                           72         624         625
# Uniform_Cost_Search                                72        5154        5156
# Greedy_Best_First_Graph_Search_H_Unmet_Goals       72          17          19
# Greedy_Best_First_Graph_Search_H_PG_Levelsum       72           9          11
# Greedy_Best_First_Graph_Search H_PG_Maxlevel       72          27          29
# Greedy_Best_First_Graph_Search_H_PG_Setlevel       72           9          11
# Astar_Search_H_Unmet_Goals                         72        2467        2469
# Astar_Search_H_PG_Levelsum                         72         357         359
# Astar_Search_H_PG_Maxlevel                         72        2887        2889
# Astar_Search H_PG_Setlevel                         72        1037        1039
#
# ...

# %%
plt.figure(figsize=(15,15))
d = defaultdict(list)

for i, x in enumerate(['Expansions','Time_Elapsed']):
    plt.subplot(1,2,i+1)
    for al in index:
        y = problem2_df.loc[al,['Actions', x]]
        z = problem1_df.loc[al,['Actions', x]]
        c = pd.concat([y,z], axis=1).transpose()
        plt.plot(c['Actions'], c[x], marker='o', label = al)
        plt.legend()
        plt.yscale('log')
        plt.xlabel('Number of Actions')
        plt.ylabel(x)
        plt.title('Number of Actions vs ' + x, fontsize=15)
plt.savefig('AINDGraph', dpi=300)

# %%
plan_length = pd.concat([problem1_df['Plan_Length'], problem2_df['Plan_Length']], axis=1)
plan_length.columns = ['Problem 1', 'Problem 2']
plan_length
# Out:
#                                               Problem 1  Problem 2
# Breadth_First_Search                                  6          9
# Depth_First_Graph_Search                             20        619
# Uniform_Cost_Search                                   6          9
# Greedy_Best_First_Graph_Search_H_Unmet_Goals          6          9
# Greedy_Best_First_Graph_Search_H_PG_Levelsum          6          9
# Greedy_Best_First_Graph_Search H_PG_Maxlevel          6          9
# Greedy_Best_First_Graph_Search_H_PG_Setlevel          6          9
# Astar_Search_H_Unmet_Goals                            6          9
# Astar_Search_H_PG_Levelsum                            6          9
# Astar_Search_H_PG_Maxlevel                            6          9
# Astar_Search H_PG_Setlevel                            6          9

# %% [markdown]
# ## Problem 3

# %%
BFS_actions_3 = 88
BFS_expansions_3 = 14663
BFS_goal_tests_3 = 18098
BFS_new_nodes_3 = 129625
BFS_plan_length_3 = 12
BFS_time_elapsed_3 = 12.253498782170936
     
DFGS_actions_3 = None #88
DFGS_expansions_3 = None #408
DFGS_goal_tests_3 = None #409
DFGS_new_nodes_3 = None #3364
DFGS_plan_length_3 = None #392
DFGS_time_elapsed_3 = None #1.2588292809668928

UCS_actions_3 = 88
UCS_expansions_3 = 18510
UCS_goal_tests_3 = 18512
UCS_new_nodes_3 = 161936
UCS_plan_length_3 = 12
UCS_time_elapsed_3 = 17.744111566105857
        
GBFGS_h_unmet_actions_3 = 88
GBFGS_h_unmet_expansions_3 = 25
GBFGS_h_unmet_goal_tests_3 = 27
GBFGS_h_unmet_new_nodes_3 = 230
GBFGS_h_unmet_plan_length_3 = 15
GBFGS_h_unmet_time_elapsed_3 = 0.039997258922085166

GBFGS_h_pg_levelsum_actions_3 = 88
GBFGS_h_pg_levelsum_expansions_3 = 14
GBFGS_h_pg_levelsum_goal_tests_3 = 16
GBFGS_h_pg_levelsum_new_nodes_3 = 126
GBFGS_h_pg_levelsum_plan_length_3 = 14
GBFGS_h_pg_levelsum_time_elapsed_3 = 14.536814170889556

GBFGS_h_pg_maxlevel_actions_3 = 88
GBFGS_h_pg_maxlevel_expansions_3 = 21
GBFGS_h_pg_maxlevel_goal_tests_3 = 23
GBFGS_h_pg_maxlevel_new_nodes_3 = 195
GBFGS_h_pg_maxlevel_plan_length_3 = 13
GBFGS_h_pg_maxlevel_time_elapsed_3 = 18.178332810057327

GBFGS_h_pg_setlevel_actions_3 = 88
GBFGS_h_pg_setlevel_expansions_3 = 35
GBFGS_h_pg_setlevel_goal_tests_3 = 37
GBFGS_h_pg_setlevel_new_nodes_3 = 345
GBFGS_h_pg_setlevel_plan_length_3 = 17
GBFGS_h_pg_setlevel_time_elapsed_3 = 80.5769023669418
        
Astar_search_h_unmet_actions_3 = 88
Astar_search_h_unmet_expansions_3 = 7388
Astar_search_h_unmet_goal_tests_3 = 7390
Astar_search_h_unmet_new_nodes_3 = 65711
Astar_search_h_unmet_plan_length_3 = 12
Astar_search_h_unmet_time_elapsed_3 = 8.31098525505513
        
Astar_search_h_pg_levelsum_actions_3 = 88
Astar_search_h_pg_levelsum_expansions_3 = 369
Astar_search_h_pg_levelsum_goal_tests_3 = 371
Astar_search_h_pg_levelsum_new_nodes_3 = 3403
Astar_search_h_pg_levelsum_plan_length_3 = 12
Astar_search_h_pg_levelsum_time_elapsed_3 = 296.60064222011715 
        
Astar_search_h_pg_maxlevel_actions_3 = 88
Astar_search_h_pg_maxlevel_expansions_3 = 9580
Astar_search_h_pg_maxlevel_goal_tests_3 = 9582
Astar_search_h_pg_maxlevel_new_nodes_3 = 86312
Astar_search_h_pg_maxlevel_plan_length_3 = 12
Astar_search_h_pg_maxlevel_time_elapsed_3 = 4742.79503794387
        
Astar_search_h_pg_setlevel_actions_3 = 88
Astar_search_h_pg_setlevel_expansions_3 = 3423
Astar_search_h_pg_setlevel_goal_tests_3 = 3425
Astar_search_h_pg_setlevel_new_nodes_3 = 31596
Astar_search_h_pg_setlevel_plan_length_3 = 12
Astar_search_h_pg_setlevel_time_elapsed_3 = 6538.669236146146

# %%
data_problem_3 = [[BFS_actions_3, BFS_expansions_3, BFS_goal_tests_3, BFS_new_nodes_3, BFS_plan_length_3, BFS_time_elapsed_3],
                 [DFGS_actions_3, DFGS_expansions_3, DFGS_goal_tests_3, DFGS_new_nodes_3, DFGS_plan_length_3, DFGS_time_elapsed_3],
                 [UCS_actions_3, UCS_expansions_3, UCS_goal_tests_3, UCS_new_nodes_3, UCS_plan_length_3, UCS_time_elapsed_3],
                 [GBFGS_h_unmet_actions_3, GBFGS_h_unmet_expansions_3, GBFGS_h_unmet_goal_tests_3, GBFGS_h_unmet_new_nodes_3, GBFGS_h_unmet_plan_length_3, GBFGS_h_unmet_time_elapsed_3],
                 [GBFGS_h_pg_levelsum_actions_3, GBFGS_h_pg_levelsum_expansions_3, GBFGS_h_pg_levelsum_goal_tests_3, GBFGS_h_pg_levelsum_new_nodes_3, GBFGS_h_pg_levelsum_plan_length_3, GBFGS_h_pg_levelsum_time_elapsed_3],
                 [GBFGS_h_pg_maxlevel_actions_3, GBFGS_h_pg_maxlevel_expansions_3, GBFGS_h_pg_maxlevel_goal_tests_3, GBFGS_h_pg_maxlevel_new_nodes_3, GBFGS_h_pg_maxlevel_plan_length_3, GBFGS_h_pg_maxlevel_time_elapsed_3],
                 [GBFGS_h_pg_setlevel_actions_3, GBFGS_h_pg_setlevel_expansions_3, GBFGS_h_pg_setlevel_goal_tests_3, GBFGS_h_pg_setlevel_new_nodes_3, GBFGS_h_pg_setlevel_plan_length_3, GBFGS_h_pg_setlevel_time_elapsed_3],
                 [Astar_search_h_unmet_actions_3, Astar_search_h_unmet_expansions_3, Astar_search_h_unmet_goal_tests_3, Astar_search_h_unmet_new_nodes_3, Astar_search_h_unmet_plan_length_3, Astar_search_h_unmet_time_elapsed_3],
                 [Astar_search_h_pg_levelsum_actions_3, Astar_search_h_pg_levelsum_expansions_3, Astar_search_h_pg_levelsum_goal_tests_3, Astar_search_h_pg_levelsum_new_nodes_3, Astar_search_h_pg_levelsum_plan_length_3, Astar_search_h_pg_levelsum_time_elapsed_3],
                 [Astar_search_h_pg_maxlevel_actions_3, Astar_search_h_pg_maxlevel_expansions_3, Astar_search_h_pg_maxlevel_goal_tests_3, Astar_search_h_pg_maxlevel_new_nodes_3, Astar_search_h_pg_maxlevel_plan_length_3, Astar_search_h_pg_maxlevel_time_elapsed_3],
                 [Astar_search_h_pg_setlevel_actions_3, Astar_search_h_pg_setlevel_expansions_3, Astar_search_h_pg_setlevel_goal_tests_3, Astar_search_h_pg_setlevel_new_nodes_3, Astar_search_h_pg_setlevel_plan_length_3, Astar_search_h_pg_setlevel_time_elapsed_3]]

problem3_df = pd.DataFrame(data=data_problem_3, columns=columns, index=index)
problem3_df
# Out:
#                                               Actions  Expansions  Goal_Tests  \
# Breadth_First_Search                             88.0     14663.0     18098.0
# Depth_First_Graph_Search                          NaN         NaN         NaN
# Uniform_Cost_Search                              88.0     18510.0     18512.0
# Greedy_Best_First_Graph_Search_H_Unmet_Goals     88.0        25.0        27.0
# Greedy_Best_First_Graph_Search_H_PG_Levelsum     88.0        14.0        16.0
# Greedy_Best_First_Graph_Search H_PG_Maxlevel     88.0        21.0        23.0
# Greedy_Best_First_Graph_Search_H_PG_Setlevel     88.0        35.0        37.0
# Astar_Search_H_Unmet_Goals                       88.0      7388.0      7390.0
# Astar_Search_H_PG_Levelsum                       88.0       369.0       371.0
# Astar_Search_H_PG_Maxlevel                       88.0      9580.0      9582.0
# Astar_Search H_PG_Setlevel                       88.0      3423.0      3425.0
#
# ...

# %% [markdown]
# ## Problem 4

# %%
BFS_actions_4 = 104
BFS_expansions_4 = 99736
BFS_goal_tests_4 = 114953
BFS_new_nodes_4 = 944130
BFS_plan_length_4 = 14
BFS_time_elapsed_4 = 108.79876113496721
     
DFGS_actions_4 = None
DFGS_expansions_4 = None
DFGS_goal_tests_4 = None
DFGS_new_nodes_4 = None
DFGS_plan_length_4 = None
DFGS_time_elapsed_4 = None

UCS_actions_4 = 104
UCS_expansions_4 = 113339
UCS_goal_tests_4 = 113341
UCS_new_nodes_4 = 1066413
UCS_plan_length_4 = 14
UCS_time_elapsed_4 = 122.52066378411837
        
GBFGS_h_unmet_actions_4 = 104
GBFGS_h_unmet_expansions_4 = 29
GBFGS_h_unmet_goal_tests_4 = 31
GBFGS_h_unmet_new_nodes_4 = 280
GBFGS_h_unmet_plan_length_4 = 18
GBFGS_h_unmet_time_elapsed_4 = 0.0731955929659307

GBFGS_h_pg_levelsum_actions_4 = 104
GBFGS_h_pg_levelsum_expansions_4 = 17
GBFGS_h_pg_levelsum_goal_tests_4 = 19
GBFGS_h_pg_levelsum_new_nodes_4 = 165
GBFGS_h_pg_levelsum_plan_length_4 = 17
GBFGS_h_pg_levelsum_time_elapsed_4 = 23.806811226997524

GBFGS_h_pg_maxlevel_actions_4 = 104
GBFGS_h_pg_maxlevel_expansions_4 = 56
GBFGS_h_pg_maxlevel_goal_tests_4 = 58
GBFGS_h_pg_maxlevel_new_nodes_4 = 580
GBFGS_h_pg_maxlevel_plan_length_4 = 17
GBFGS_h_pg_maxlevel_time_elapsed_4 = 64.69224981497973

GBFGS_h_pg_setlevel_actions_4 = 104
GBFGS_h_pg_setlevel_expansions_4 = 107
GBFGS_h_pg_setlevel_goal_tests_4 = 109
GBFGS_h_pg_setlevel_new_nodes_4 = 1164
GBFGS_h_pg_setlevel_plan_length_4 = 23
GBFGS_h_pg_setlevel_time_elapsed_4 = 376.4564914191142
        
Astar_search_h_unmet_actions_4 = 104
Astar_search_h_unmet_expansions_4 = 34330
Astar_search_h_unmet_goal_tests_4 = 34332
Astar_search_h_unmet_new_nodes_4 = 328509
Astar_search_h_unmet_plan_length_4 = 14
Astar_search_h_unmet_time_elapsed_4 = 59.0700491941534
        
Astar_search_h_pg_levelsum_actions_4 = 104
Astar_search_h_pg_levelsum_expansions_4 = 1208
Astar_search_h_pg_levelsum_goal_tests_4 = 1210
Astar_search_h_pg_levelsum_new_nodes_4 = 12210
Astar_search_h_pg_levelsum_plan_length_4 = 15
Astar_search_h_pg_levelsum_time_elapsed_4 = 1513.1473877278622
        
Astar_search_h_pg_maxlevel_actions_4 = None
Astar_search_h_pg_maxlevel_expansions_4 = None
Astar_search_h_pg_maxlevel_goal_tests_4 = None
Astar_search_h_pg_maxlevel_new_nodes_4 = None
Astar_search_h_pg_maxlevel_plan_length_4 = None
Astar_search_h_pg_maxlevel_time_elapsed_4 = None
        
Astar_search_h_pg_setlevel_actions_4 = None
Astar_search_h_pg_setlevel_expansions_4 = None
Astar_search_h_pg_setlevel_goal_tests_4 = None
Astar_search_h_pg_setlevel_new_nodes_4 = None
Astar_search_h_pg_setlevel_plan_length_4 = None
Astar_search_h_pg_setlevel_time_elapsed_4 = None

# %%
data_problem_4 = [[BFS_actions_4, BFS_expansions_4, BFS_goal_tests_4, BFS_new_nodes_4, BFS_plan_length_4, BFS_time_elapsed_4],
                 [DFGS_actions_4, DFGS_expansions_4, DFGS_goal_tests_4, DFGS_new_nodes_4, DFGS_plan_length_4, DFGS_time_elapsed_4],
                 [UCS_actions_4, UCS_expansions_4, UCS_goal_tests_4, UCS_new_nodes_4, UCS_plan_length_4, UCS_time_elapsed_4],
                 [GBFGS_h_unmet_actions_4, GBFGS_h_unmet_expansions_4, GBFGS_h_unmet_goal_tests_4, GBFGS_h_unmet_new_nodes_4, GBFGS_h_unmet_plan_length_4, GBFGS_h_unmet_time_elapsed_4],
                 [GBFGS_h_pg_levelsum_actions_4, GBFGS_h_pg_levelsum_expansions_4, GBFGS_h_pg_levelsum_goal_tests_4, GBFGS_h_pg_levelsum_new_nodes_4, GBFGS_h_pg_levelsum_plan_length_4, GBFGS_h_pg_levelsum_time_elapsed_4],
                 [GBFGS_h_pg_maxlevel_actions_4, GBFGS_h_pg_maxlevel_expansions_4, GBFGS_h_pg_maxlevel_goal_tests_4, GBFGS_h_pg_maxlevel_new_nodes_4, GBFGS_h_pg_maxlevel_plan_length_4, GBFGS_h_pg_maxlevel_time_elapsed_4],
                 [GBFGS_h_pg_setlevel_actions_4, GBFGS_h_pg_setlevel_expansions_4, GBFGS_h_pg_setlevel_goal_tests_4, GBFGS_h_pg_setlevel_new_nodes_4, GBFGS_h_pg_setlevel_plan_length_4, GBFGS_h_pg_setlevel_time_elapsed_4],
                 [Astar_search_h_unmet_actions_4, Astar_search_h_unmet_expansions_4, Astar_search_h_unmet_goal_tests_4, Astar_search_h_unmet_new_nodes_4, Astar_search_h_unmet_plan_length_4, Astar_search_h_unmet_time_elapsed_4],
                 [Astar_search_h_pg_levelsum_actions_4, Astar_search_h_pg_levelsum_expansions_4, Astar_search_h_pg_levelsum_goal_tests_4, Astar_search_h_pg_levelsum_new_nodes_4, Astar_search_h_pg_levelsum_plan_length_4, Astar_search_h_pg_levelsum_time_elapsed_4],
                 [Astar_search_h_pg_maxlevel_actions_4, Astar_search_h_pg_maxlevel_expansions_4, Astar_search_h_pg_maxlevel_goal_tests_4, Astar_search_h_pg_maxlevel_new_nodes_4, Astar_search_h_pg_maxlevel_plan_length_4, Astar_search_h_pg_maxlevel_time_elapsed_4],
                 [Astar_search_h_pg_setlevel_actions_4, Astar_search_h_pg_setlevel_expansions_4, Astar_search_h_pg_setlevel_goal_tests_4, Astar_search_h_pg_setlevel_new_nodes_4, Astar_search_h_pg_setlevel_plan_length_4, Astar_search_h_pg_setlevel_time_elapsed_4]]

problem4_df = pd.DataFrame(data=data_problem_4, columns=columns, index=index)
problem4_df
# Out:
#                                               Actions  Expansions  Goal_Tests  \
# Breadth_First_Search                            104.0     99736.0    114953.0
# Depth_First_Graph_Search                          NaN         NaN         NaN
# Uniform_Cost_Search                             104.0    113339.0    113341.0
# Greedy_Best_First_Graph_Search_H_Unmet_Goals    104.0        29.0        31.0
# Greedy_Best_First_Graph_Search_H_PG_Levelsum    104.0        17.0        19.0
# Greedy_Best_First_Graph_Search H_PG_Maxlevel    104.0        56.0        58.0
# Greedy_Best_First_Graph_Search_H_PG_Setlevel    104.0       107.0       109.0
# Astar_Search_H_Unmet_Goals                      104.0     34330.0     34332.0
# Astar_Search_H_PG_Levelsum                      104.0      1208.0      1210.0
# Astar_Search_H_PG_Maxlevel                        NaN         NaN         NaN
# Astar_Search H_PG_Setlevel                        NaN         NaN         NaN
#
# ...

# %%
plt.figure(figsize=(20,20))
d = defaultdict(list)

for i, x in enumerate(['Expansions','Time_Elapsed']):
    plt.subplot(1,2,i+1)
    for al in index:
        p4 = problem4_df.loc[al,['Actions', x]]
        p3 = problem3_df.loc[al,['Actions', x]]
        p2 = problem2_df.loc[al,['Actions', x]]
        p1 = problem1_df.loc[al,['Actions', x]]
        c = pd.concat([p1, p2, p3, p4], axis=1).transpose()
        plt.plot(c['Actions'], c[x], marker='o', label = al)
        plt.legend()
        plt.yscale('log')
        plt.xlabel('Number of Actions')
        plt.ylabel(x)
        plt.title('Number of Actions vs ' + x, fontsize=15)
plt.savefig('AINDGraph2', dpi=300)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000
